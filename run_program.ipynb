# %%
from get_image import get_image
from facenet2 import describe_image, show_imagebox
from matching_py import *
from Profile import *
import pickle

def run_program():
    
    with open("database.pkl", mode="rb") as database:
        database = pickle.load(database)
    
    print(database)
        
    image, check_or_load = get_image()
    descriptors, boxes, probabilities, landmarks = describe_image(image)
    show_imagebox(image, boxes, probabilities, landmarks)
    profile = Profile()
    
    if check_or_load.lower() == 'load':
        name = input("Please insert name of person")
        profile(database, name, descriptors)
    
    elif check_or_load.lower() == 'check':
        match = matching(database, descriptors, 0.5)

# %%
with open("database.pkl", mode="wb") as database:
    pickle.dump({}, database)

# %%
run_program()
# Out:
# {}
# Camera or Image?: camera
# <img src="data:image/png;base64,..." width="640">
# Are you loading or checking your image?load
# <img src="data:image/png;base64,..." width="640">
# Please insert name of personJamie
